# %%
data_dir = "/content/drive/MyDrive/Colab Notebooks/Licenta/lfw50"

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Count images per class
classes = os.listdir(data_dir)
counts = {cls: len(os.listdir(os.path.join(data_dir, cls))) for cls in classes if os.path.isdir(os.path.join(data_dir, cls))}
df_dist = pd.DataFrame(list(counts.items()), columns=['Class', 'Count']).sort_values(by='Count', ascending=False)

# Plot distribution
plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='Class', data=df_dist.head(20))
plt.title('Top 20 Classes Distribution in LFW50')
plt.show()

# %%
import tensorflow as tf

# Using the directory defined in the first cell
img_height, img_width = 224, 224
batch_size = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

class_names = train_ds.class_names
print(f"Classes: {class_names}")
# Out:
# Found 600 files belonging to 12 classes.
# Using 480 files for training.
# Found 600 files belonging to 12 classes.
# Using 120 files for validation.
# Classes: ['Ariel_Sharon', 'Colin_Powell', 'Donald_Rumsfeld', 'George_W_Bush', 'Gerhard_Schroeder', 'Hugo_Chavez', 'Jacques_Chirac', 'Jean_Chretien', 'John_Ashcroft', 'Junichiro_Koizumi', 'Serena_Williams', 'Tony_Blair']

# %%
# Switching model to TensorFlow Keras to match the new data loading method
num_classes = len(class_names)

base_model = tf.keras.applications.ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)
base_model.trainable = False  # Freeze base layers

# Renaming the model as requested
PersonCNN_ResNet50_lfw50 = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

PersonCNN_ResNet50_lfw50.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

PersonCNN_ResNet50_lfw50.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 12)             │        24,588 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,612,300 (90.07 MB)
#  Trainable params: 24,588 (96.05 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# 1. Unfreeze the top layers of the base model for fine-tuning
base_model.trainable = True
# We'll freeze all layers except the last 15
fine_tune_at = len(base_model.layers) - 15
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# 2. Re-build with the enhanced head
PersonCNN_ResNet50_lfw50 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224, 224, 3)),
    data_augmentation,
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# 3. Use a very low learning rate for fine-tuning to avoid wrecking pre-trained weights
initial_learning_rate = 1e-5

PersonCNN_ResNet50_lfw50.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# 4. Add a Learning Rate Scheduler to the callbacks in the next cell
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

print("Model configured for Fine-Tuning (Last 15 layers unfrozen).")
print(f"Initial fine-tuning learning rate: {initial_learning_rate}")
# Out:
# Model configured for Fine-Tuning (Last 15 layers unfrozen).
# Initial fine-tuning learning rate: 1e-05

# %% [markdown]
# ### Next Step: Fine-Tuning
# If augmentation isn't enough, we can unfreeze the last few layers of ResNet50:
# ```python
# base_model.trainable = True
# # Fine-tune from this layer onwards
# fine_tune_at = 140
# for layer in base_model.layers[:fine_tune_at]:
#     layer.trainable = False
#
# # Recompile with a MUCH smaller learning rate
# PersonCNN_ResNet50_lfw50.compile(
#     optimizer=tf.keras.optimizers.Adam(1e-5),
#     loss='sparse_categorical_crossentropy',
#     metrics=['accuracy']
# )
# ```

# %%
# Custom callback to save every N epochs
class PeriodicModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath, save_freq_epochs=2):
        super().__init__()
        self.filepath = filepath
        self.save_freq_epochs = save_freq_epochs

    def on_epoch_end(self, epoch, logs=None):
        actual_epoch = epoch + 1
        if actual_epoch % self.save_freq_epochs == 0:
            path = self.filepath.format(epoch=actual_epoch, **logs)
            self.model.save(path)
            print(f"\nEpoch {actual_epoch}: saving model to {path}")

checkpoint_dir = "/content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints"
model_name = "PersonCNN_ResNet50_lfw50_FT"
checkpoint_path = os.path.join(checkpoint_dir, f"{model_name}_epoch_{{epoch:02d}}_val_acc_{{val_accuracy:.4f}}.keras")

cp_callback = PeriodicModelCheckpoint(checkpoint_path, save_freq_epochs=2)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=8,
    restore_best_weights=True
)

# Training with Fine-Tuning and LR Scheduler
history = PersonCNN_ResNet50_lfw50.fit(
    train_ds,
    validation_data=val_ds,
    epochs=230,
    callbacks=[cp_callback, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.0896 - loss: 3.5257 - val_accuracy: 0.0917 - val_loss: 2.5894 - learning_rate: 1.0000e-05
# Epoch 2/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.0912 - loss: 3.4595
# Epoch 2: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_02_val_acc_0.0917.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 399ms/step - accuracy: 0.0958 - loss: 3.4586 - val_accuracy: 0.0917 - val_loss: 2.5537 - learning_rate: 1.0000e-05
# Epoch 3/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - accuracy: 0.0917 - loss: 3.3866 - val_accuracy: 0.1167 - val_loss: 2.5352 - learning_rate: 1.0000e-05
# Epoch 4/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.0849 - loss: 3.3894
# Epoch 4: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_04_val_acc_0.1167.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.0854 - loss: 3.4229 - val_accuracy: 0.1167 - val_loss: 2.5292 - learning_rate: 1.0000e-05
# Epoch 5/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.0938 - loss: 3.3050 - val_accuracy: 0.1083 - val_loss: 2.5273 - learning_rate: 1.0000e-05
# Epoch 6/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.1079 - loss: 3.1909
# Epoch 6: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_06_val_acc_0.1083.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 359ms/step - accuracy: 0.1229 - loss: 3.1658 - val_accuracy: 0.1083 - val_loss: 2.5268 - learning_rate: 1.0000e-05
# Epoch 7/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 250ms/step - accuracy: 0.1333 - loss: 3.1259 - val_accuracy: 0.1083 - val_loss: 2.5220 - learning_rate: 1.0000e-05
# Epoch 8/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.1633 - loss: 3.0374
# Epoch 8: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_08_val_acc_0.1250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 383ms/step - accuracy: 0.1542 - loss: 3.0314 - val_accuracy: 0.1250 - val_loss: 2.5134 - learning_rate: 1.0000e-05
# Epoch 9/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - accuracy: 0.1417 - loss: 3.1198 - val_accuracy: 0.1333 - val_loss: 2.5031 - learning_rate: 1.0000e-05
# Epoch 10/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.1441 - loss: 3.0032
# Epoch 10: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_10_val_acc_0.1250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - accuracy: 0.1646 - loss: 2.9831 - val_accuracy: 0.1250 - val_loss: 2.4913 - learning_rate: 1.0000e-05
# Epoch 11/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.1729 - loss: 2.9535 - val_accuracy: 0.1833 - val_loss: 2.4776 - learning_rate: 1.0000e-05
# Epoch 12/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.1931 - loss: 2.7993
# Epoch 12: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_12_val_acc_0.2000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.1792 - loss: 2.8461 - val_accuracy: 0.2000 - val_loss: 2.4592 - learning_rate: 1.0000e-05
# Epoch 13/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - accuracy: 0.1854 - loss: 2.7550 - val_accuracy: 0.2083 - val_loss: 2.4385 - learning_rate: 1.0000e-05
# Epoch 14/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.2160 - loss: 2.6966
# Epoch 14: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_14_val_acc_0.2167.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 367ms/step - accuracy: 0.2125 - loss: 2.7433 - val_accuracy: 0.2167 - val_loss: 2.4185 - learning_rate: 1.0000e-05
# Epoch 15/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.2000 - loss: 2.7425 - val_accuracy: 0.2417 - val_loss: 2.3888 - learning_rate: 1.0000e-05
# Epoch 16/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.2490 - loss: 2.5853
# Epoch 16: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_16_val_acc_0.2417.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.2479 - loss: 2.5592 - val_accuracy: 0.2417 - val_loss: 2.3616 - learning_rate: 1.0000e-05
# Epoch 17/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.2208 - loss: 2.5919 - val_accuracy: 0.2500 - val_loss: 2.3382 - learning_rate: 1.0000e-05
# Epoch 18/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2647 - loss: 2.4583
# Epoch 18: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_18_val_acc_0.2583.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 853ms/step - accuracy: 0.2542 - loss: 2.4685 - val_accuracy: 0.2583 - val_loss: 2.3045 - learning_rate: 1.0000e-05
# Epoch 19/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - accuracy: 0.2562 - loss: 2.5432 - val_accuracy: 0.2667 - val_loss: 2.2746 - learning_rate: 1.0000e-05
# Epoch 20/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.2517 - loss: 2.5176
# Epoch 20: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_20_val_acc_0.2667.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.2396 - loss: 2.5239 - val_accuracy: 0.2667 - val_loss: 2.2427 - learning_rate: 1.0000e-05
# Epoch 21/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 394ms/step - accuracy: 0.2896 - loss: 2.3973 - val_accuracy: 0.2833 - val_loss: 2.2211 - learning_rate: 1.0000e-05
# Epoch 22/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.2450 - loss: 2.4150
# Epoch 22: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_22_val_acc_0.3000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 684ms/step - accuracy: 0.2750 - loss: 2.3892 - val_accuracy: 0.3000 - val_loss: 2.1955 - learning_rate: 1.0000e-05
# Epoch 23/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - accuracy: 0.3146 - loss: 2.2061 - val_accuracy: 0.3000 - val_loss: 2.1697 - learning_rate: 1.0000e-05
# Epoch 24/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.3307 - loss: 2.1905
# Epoch 24: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_24_val_acc_0.3250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 782ms/step - accuracy: 0.3250 - loss: 2.2332 - val_accuracy: 0.3250 - val_loss: 2.1405 - learning_rate: 1.0000e-05
# Epoch 25/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.2833 - loss: 2.3316 - val_accuracy: 0.3250 - val_loss: 2.1099 - learning_rate: 1.0000e-05
# Epoch 26/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.3081 - loss: 2.1293
# Epoch 26: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_26_val_acc_0.3333.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 489ms/step - accuracy: 0.3146 - loss: 2.1150 - val_accuracy: 0.3333 - val_loss: 2.0828 - learning_rate: 1.0000e-05
# Epoch 27/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - accuracy: 0.3187 - loss: 2.1319 - val_accuracy: 0.3250 - val_loss: 2.0557 - learning_rate: 1.0000e-05
# Epoch 28/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.3952 - loss: 2.0046
# Epoch 28: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_28_val_acc_0.3250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 371ms/step - accuracy: 0.3896 - loss: 2.0346 - val_accuracy: 0.3250 - val_loss: 2.0305 - learning_rate: 1.0000e-05
# Epoch 29/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.3417 - loss: 2.0406 - val_accuracy: 0.3250 - val_loss: 2.0115 - learning_rate: 1.0000e-05
# Epoch 30/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.3935 - loss: 1.9679
# Epoch 30: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_30_val_acc_0.3250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.3688 - loss: 2.0312 - val_accuracy: 0.3250 - val_loss: 1.9911 - learning_rate: 1.0000e-05
# Epoch 31/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.3521 - loss: 2.0489 - val_accuracy: 0.3417 - val_loss: 1.9693 - learning_rate: 1.0000e-05
# Epoch 32/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.3860 - loss: 1.9729
# Epoch 32: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_32_val_acc_0.3417.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.3812 - loss: 1.9810 - val_accuracy: 0.3417 - val_loss: 1.9438 - learning_rate: 1.0000e-05
# Epoch 33/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - accuracy: 0.4000 - loss: 1.8974 - val_accuracy: 0.3667 - val_loss: 1.9174 - learning_rate: 1.0000e-05
# Epoch 34/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.3782 - loss: 1.9081
# Epoch 34: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_34_val_acc_0.3667.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 398ms/step - accuracy: 0.3792 - loss: 1.8783 - val_accuracy: 0.3667 - val_loss: 1.9005 - learning_rate: 1.0000e-05
# Epoch 35/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - accuracy: 0.4167 - loss: 1.8794 - val_accuracy: 0.3750 - val_loss: 1.8790 - learning_rate: 1.0000e-05
# Epoch 36/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.4721 - loss: 1.7077
# Epoch 36: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_36_val_acc_0.3750.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.4417 - loss: 1.7836 - val_accuracy: 0.3750 - val_loss: 1.8538 - learning_rate: 1.0000e-05
# Epoch 37/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - accuracy: 0.4250 - loss: 1.7791 - val_accuracy: 0.3917 - val_loss: 1.8270 - learning_rate: 1.0000e-05
# Epoch 38/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.4202 - loss: 1.7282
# Epoch 38: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_38_val_acc_0.4000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 367ms/step - accuracy: 0.4292 - loss: 1.7174 - val_accuracy: 0.4000 - val_loss: 1.8021 - learning_rate: 1.0000e-05
# Epoch 39/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - accuracy: 0.4521 - loss: 1.6456 - val_accuracy: 0.4083 - val_loss: 1.7810 - learning_rate: 1.0000e-05
# Epoch 40/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.4458 - loss: 1.7196
# Epoch 40: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_40_val_acc_0.4250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 378ms/step - accuracy: 0.4771 - loss: 1.6511 - val_accuracy: 0.4250 - val_loss: 1.7590 - learning_rate: 1.0000e-05
# Epoch 41/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - accuracy: 0.4729 - loss: 1.6493 - val_accuracy: 0.4417 - val_loss: 1.7399 - learning_rate: 1.0000e-05
# Epoch 42/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5086 - loss: 1.6069
# Epoch 42: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_42_val_acc_0.4417.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.4958 - loss: 1.6455 - val_accuracy: 0.4417 - val_loss: 1.7202 - learning_rate: 1.0000e-05
# Epoch 43/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 276ms/step - accuracy: 0.4542 - loss: 1.6505 - val_accuracy: 0.4500 - val_loss: 1.7015 - learning_rate: 1.0000e-05
# Epoch 44/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.4675 - loss: 1.6342
# Epoch 44: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_44_val_acc_0.4667.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step - accuracy: 0.4792 - loss: 1.6008 - val_accuracy: 0.4667 - val_loss: 1.6864 - learning_rate: 1.0000e-05
# Epoch 45/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.4979 - loss: 1.6058 - val_accuracy: 0.4583 - val_loss: 1.6659 - learning_rate: 1.0000e-05
# Epoch 46/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.5088 - loss: 1.5349
# Epoch 46: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_46_val_acc_0.4750.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 412ms/step - accuracy: 0.5292 - loss: 1.4814 - val_accuracy: 0.4750 - val_loss: 1.6457 - learning_rate: 1.0000e-05
# Epoch 47/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.5083 - loss: 1.5171 - val_accuracy: 0.4833 - val_loss: 1.6273 - learning_rate: 1.0000e-05
# Epoch 48/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.4915 - loss: 1.5256
# Epoch 48: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_48_val_acc_0.4750.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - accuracy: 0.5063 - loss: 1.5024 - val_accuracy: 0.4750 - val_loss: 1.6074 - learning_rate: 1.0000e-05
# Epoch 49/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.5271 - loss: 1.4482 - val_accuracy: 0.4833 - val_loss: 1.5866 - learning_rate: 1.0000e-05
# Epoch 50/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5788 - loss: 1.3682
# Epoch 50: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_50_val_acc_0.4833.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 341ms/step - accuracy: 0.5542 - loss: 1.4359 - val_accuracy: 0.4833 - val_loss: 1.5684 - learning_rate: 1.0000e-05
# Epoch 51/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.5375 - loss: 1.4643 - val_accuracy: 0.5000 - val_loss: 1.5509 - learning_rate: 1.0000e-05
# Epoch 52/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.6053 - loss: 1.2280
# Epoch 52: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_52_val_acc_0.5083.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 719ms/step - accuracy: 0.5646 - loss: 1.3305 - val_accuracy: 0.5083 - val_loss: 1.5321 - learning_rate: 1.0000e-05
# Epoch 53/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - accuracy: 0.5562 - loss: 1.3289 - val_accuracy: 0.5083 - val_loss: 1.5131 - learning_rate: 1.0000e-05
# Epoch 54/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.5116 - loss: 1.4538
# Epoch 54: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_54_val_acc_0.5250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 808ms/step - accuracy: 0.5396 - loss: 1.3786 - val_accuracy: 0.5250 - val_loss: 1.4909 - learning_rate: 1.0000e-05
# Epoch 55/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.5562 - loss: 1.2919 - val_accuracy: 0.5500 - val_loss: 1.4646 - learning_rate: 1.0000e-05
# Epoch 56/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5948 - loss: 1.3018
# Epoch 56: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_56_val_acc_0.5583.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 506ms/step - accuracy: 0.5854 - loss: 1.2838 - val_accuracy: 0.5583 - val_loss: 1.4456 - learning_rate: 1.0000e-05
# Epoch 57/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - accuracy: 0.5833 - loss: 1.2360 - val_accuracy: 0.5583 - val_loss: 1.4308 - learning_rate: 1.0000e-05
# Epoch 58/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6311 - loss: 1.2348
# Epoch 58: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_58_val_acc_0.5667.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 386ms/step - accuracy: 0.6208 - loss: 1.2132 - val_accuracy: 0.5667 - val_loss: 1.4113 - learning_rate: 1.0000e-05
# Epoch 59/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - accuracy: 0.6042 - loss: 1.2515 - val_accuracy: 0.5750 - val_loss: 1.3973 - learning_rate: 1.0000e-05
# Epoch 60/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.6266 - loss: 1.1567
# Epoch 60: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_60_val_acc_0.5667.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.6187 - loss: 1.1501 - val_accuracy: 0.5667 - val_loss: 1.3830 - learning_rate: 1.0000e-05
# Epoch 61/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.6021 - loss: 1.1655 - val_accuracy: 0.5750 - val_loss: 1.3655 - learning_rate: 1.0000e-05
# Epoch 62/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6310 - loss: 1.1741
# Epoch 62: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_62_val_acc_0.5833.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 338ms/step - accuracy: 0.6354 - loss: 1.2016 - val_accuracy: 0.5833 - val_loss: 1.3444 - learning_rate: 1.0000e-05
# Epoch 63/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.6187 - loss: 1.1396 - val_accuracy: 0.6000 - val_loss: 1.3228 - learning_rate: 1.0000e-05
# Epoch 64/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6328 - loss: 1.1676
# Epoch 64: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_64_val_acc_0.6083.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - accuracy: 0.6396 - loss: 1.1646 - val_accuracy: 0.6083 - val_loss: 1.3108 - learning_rate: 1.0000e-05
# Epoch 65/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - accuracy: 0.6500 - loss: 1.1237 - val_accuracy: 0.6083 - val_loss: 1.3002 - learning_rate: 1.0000e-05
# Epoch 66/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.6848 - loss: 1.0023
# Epoch 66: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_66_val_acc_0.6083.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.6625 - loss: 1.0730 - val_accuracy: 0.6083 - val_loss: 1.2885 - learning_rate: 1.0000e-05
# Epoch 67/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - accuracy: 0.6687 - loss: 1.0108 - val_accuracy: 0.6083 - val_loss: 1.2697 - learning_rate: 1.0000e-05
# Epoch 68/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6874 - loss: 1.0953
# Epoch 68: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_68_val_acc_0.6083.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 307ms/step - accuracy: 0.6646 - loss: 1.0842 - val_accuracy: 0.6083 - val_loss: 1.2548 - learning_rate: 1.0000e-05
# Epoch 69/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step - accuracy: 0.6646 - loss: 1.0396 - val_accuracy: 0.6083 - val_loss: 1.2376 - learning_rate: 1.0000e-05
# Epoch 70/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6237 - loss: 1.0658
# Epoch 70: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_70_val_acc_0.6167.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 398ms/step - accuracy: 0.6500 - loss: 1.0683 - val_accuracy: 0.6167 - val_loss: 1.2196 - learning_rate: 1.0000e-05
# Epoch 71/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - accuracy: 0.6812 - loss: 0.9965 - val_accuracy: 0.6167 - val_loss: 1.2051 - learning_rate: 1.0000e-05
# Epoch 72/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7066 - loss: 0.9389
# Epoch 72: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_72_val_acc_0.6333.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 0.6792 - loss: 0.9940 - val_accuracy: 0.6333 - val_loss: 1.1888 - learning_rate: 1.0000e-05
# Epoch 73/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.7042 - loss: 0.9438 - val_accuracy: 0.6333 - val_loss: 1.1748 - learning_rate: 1.0000e-05
# Epoch 74/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0
230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 299ms/step - accuracy: 0.7417 - loss: 0.8097 - val_accuracy: 0.7250 - val_loss: 0.9697 - learning_rate: 1.0000e-05
# Epoch 90/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7472 - loss: 0.7596
# Epoch 90: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_90_val_acc_0.7250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.7437 - loss: 0.7581 - val_accuracy: 0.7250 - val_loss: 0.9597 - learning_rate: 1.0000e-05
# Epoch 91/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - accuracy: 0.7437 - loss: 0.7770 - val_accuracy: 0.7250 - val_loss: 0.9466 - learning_rate: 1.0000e-05
# Epoch 92/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8253 - loss: 0.6079
# Epoch 92: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_92_val_acc_0.7250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 359ms/step - accuracy: 0.7937 - loss: 0.6634 - val_accuracy: 0.7250 - val_loss: 0.9341 - learning_rate: 1.0000e-05
# Epoch 93/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - accuracy: 0.8125 - loss: 0.6557 - val_accuracy: 0.7167 - val_loss: 0.9247 - learning_rate: 1.0000e-05
# Epoch 94/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8096 - loss: 0.6131
# Epoch 94: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_94_val_acc_0.7167.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - accuracy: 0.8021 - loss: 0.6354 - val_accuracy: 0.7167 - val_loss: 0.9165 - learning_rate: 1.0000e-05
# Epoch 95/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - accuracy: 0.8000 - loss: 0.6117 - val_accuracy: 0.7167 - val_loss: 0.9143 - learning_rate: 1.0000e-05
# Epoch 96/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7793 - loss: 0.6793
# Epoch 96: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_96_val_acc_0.7167.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - accuracy: 0.8062 - loss: 0.6513 - val_accuracy: 0.7167 - val_loss: 0.9095 - learning_rate: 1.0000e-05
# Epoch 97/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 241ms/step - accuracy: 0.8083 - loss: 0.6320 - val_accuracy: 0.7250 - val_loss: 0.9063 - learning_rate: 1.0000e-05
# Epoch 98/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7892 - loss: 0.6233
# Epoch 98: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_98_val_acc_0.7167.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 413ms/step - accuracy: 0.7937 - loss: 0.6290 - val_accuracy: 0.7167 - val_loss: 0.9005 - learning_rate: 1.0000e-05
# Epoch 99/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - accuracy: 0.8354 - loss: 0.5866 - val_accuracy: 0.7250 - val_loss: 0.8917 - learning_rate: 1.0000e-05
# Epoch 100/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8528 - loss: 0.5111
# Epoch 100: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_100_val_acc_0.7250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.8542 - loss: 0.5166 - val_accuracy: 0.7250 - val_loss: 0.8875 - learning_rate: 1.0000e-05
# Epoch 101/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.8250 - loss: 0.5977 - val_accuracy: 0.7250 - val_loss: 0.8781 - learning_rate: 1.0000e-05
# Epoch 102/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8068 - loss: 0.6078
# Epoch 102: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_102_val_acc_0.7167.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.8208 - loss: 0.5842 - val_accuracy: 0.7167 - val_loss: 0.8741 - learning_rate: 1.0000e-05
# Epoch 103/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - accuracy: 0.8333 - loss: 0.5855 - val_accuracy: 0.7167 - val_loss: 0.8684 - learning_rate: 1.0000e-05
# Epoch 104/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7906 - loss: 0.6105
# Epoch 104: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_104_val_acc_0.7333.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 386ms/step - accuracy: 0.8229 - loss: 0.5606 - val_accuracy: 0.7333 - val_loss: 0.8631 - learning_rate: 1.0000e-05
# Epoch 105/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step
230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 431ms/step - accuracy: 0.9083 - loss: 0.3444 - val_accuracy: 0.8000 - val_loss: 0.6731 - learning_rate: 1.0000e-05
# Epoch 138/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9042 - loss: 0.3485
# Epoch 138: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_138_val_acc_0.8000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.9083 - loss: 0.3509 - val_accuracy: 0.8000 - val_loss: 0.6692 - learning_rate: 1.0000e-05
# Epoch 139/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - accuracy: 0.9125 - loss: 0.3144 - val_accuracy: 0.8000 - val_loss: 0.6688 - learning_rate: 1.0000e-05
# Epoch 140/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9013 - loss: 0.3192
# Epoch 140: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_140_val_acc_0.8000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step - accuracy: 0.8875 - loss: 0.3483 - val_accuracy: 0.8000 - val_loss: 0.6636 - learning_rate: 1.0000e-05
# Epoch 141/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 249ms/step - accuracy: 0.9062 - loss: 0.3305 - val_accuracy: 0.7917 - val_loss: 0.6583 - learning_rate: 1.0000e-05
# Epoch 142/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9316 - loss: 0.3007
# Epoch 142: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_142_val_acc_0.7917.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 410ms/step - accuracy: 0.9312 - loss: 0.3000 - val_accuracy: 0.7917 - val_loss: 0.6527 - learning_rate: 1.0000e-05
# Epoch 143/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 232ms/step - accuracy: 0.9292 - loss: 0.2871 - val_accuracy: 0.7917 - val_loss: 0.6474 - learning_rate: 1.0000e-05
# Epoch 144/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9456 - loss: 0.2602
# Epoch 144: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_144_val_acc_0.7917.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.9250 - loss: 0.2945 - val_accuracy: 0.7917 - val_loss: 0.6443 - learning_rate: 1.0000e-05
# Epoch 145/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 253ms/step - accuracy: 0.9229 - loss: 0.2830 - val_accuracy: 0.7917 - val_loss: 0.6393 - learning_rate: 1.0000e-05
# Epoch 146/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9113 - loss: 0.3143
# Epoch 146: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_146_val_acc_0.7917.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9146 - loss: 0.3314 - val_accuracy: 0.7917 - val_loss: 0.6349 - learning_rate: 1.0000e-05
# Epoch 147/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - accuracy: 0.9250 - loss: 0.2880 - val_accuracy: 0.8000 - val_loss: 0.6319 - learning_rate: 1.0000e-05
# Epoch 148/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9143 - loss: 0.2944
# Epoch 148: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_148_val_acc_0.8000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 376ms/step - accuracy: 0.9083 - loss: 0.3200 - val_accuracy: 0.8000 - val_loss: 0.6297 - learning_rate: 1.0000e-05
# Epoch 149/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - accuracy: 0.9333 - loss: 0.2926 - val_accuracy: 0.8000 - val_loss: 0.6269 - learning_rate: 1.0000e-05
# Epoch 150/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9308 - loss: 0.2695
# Epoch 150: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_150_val_acc_0.8000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 357ms/step - accuracy: 0.9229 - loss: 0.3030 - val_accuracy: 0.8000 - val_loss: 0.6227 - learning_rate: 1.0000e-05
# Epoch 151/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.9208 - loss: 0.2752 - val_accuracy: 0.7917 - val_loss: 0.6174 - learning_rate: 1.0000e-05
# Epoch 152/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9273 - loss: 0.2576
# Epoch 152: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_152_val_acc_0.8000.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/
saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_168_val_acc_0.8250.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.9417 - loss: 0.2204 - val_accuracy: 0.8250 - val_loss: 0.5529 - learning_rate: 1.0000e-05
# Epoch 169/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - accuracy: 0.9375 - loss: 0.2325 - val_accuracy: 0.8250 - val_loss: 0.5509 - learning_rate: 1.0000e-05
# Epoch 170/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9336 - loss: 0.2298
# Epoch 170: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_170_val_acc_0.8333.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - accuracy: 0.9396 - loss: 0.2165 - val_accuracy: 0.8333 - val_loss: 0.5465 - learning_rate: 1.0000e-05
# Epoch 171/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 244ms/step - accuracy: 0.9292 - loss: 0.2482 - val_accuracy: 0.8417 - val_loss: 0.5424 - learning_rate: 1.0000e-05
# Epoch 172/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9613 - loss: 0.1584
# Epoch 172: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_172_val_acc_0.8417.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 369ms/step - accuracy: 0.9438 - loss: 0.1987 - val_accuracy: 0.8417 - val_loss: 0.5405 - learning_rate: 1.0000e-05
# Epoch 173/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - accuracy: 0.9563 - loss: 0.1921 - val_accuracy: 0.8500 - val_loss: 0.5354 - learning_rate: 1.0000e-05
# Epoch 174/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9492 - loss: 0.2020
# Epoch 174: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_174_val_acc_0.8417.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 413ms/step - accuracy: 0.9438 - loss: 0.1990 - val_accuracy: 0.8417 - val_loss: 0.5335 - learning_rate: 1.0000e-05
# Epoch 175/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.9417 - loss: 0.2111 - val_accuracy: 0.8500 - val_loss: 0.5299 - learning_rate: 1.0000e-05
# Epoch 176/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9543 - loss: 0.2028
# Epoch 176: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_176_val_acc_0.8417.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 708ms/step - accuracy: 0.9604 - loss: 0.2043 - val_accuracy: 0.8417 - val_loss: 0.5305 - learning_rate: 1.0000e-05
# Epoch 177/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step - accuracy: 0.9458 - loss: 0.1849 - val_accuracy: 0.8417 - val_loss: 0.5288 - learning_rate: 1.0000e-05
# Epoch 178/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9605 - loss: 0.1884
# Epoch 178: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_178_val_acc_0.8417.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 362ms/step - accuracy: 0.9542 - loss: 0.2092 - val_accuracy: 0.8417 - val_loss: 0.5254 - learning_rate: 1.0000e-05
# Epoch 179/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 483ms/step - accuracy: 0.9563 - loss: 0.1861 - val_accuracy: 0.8417 - val_loss: 0.5237 - learning_rate: 1.0000e-05
# Epoch 180/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9623 - loss: 0.1661
# Epoch 180: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_180_val_acc_0.8500.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - accuracy: 0.9625 - loss: 0.1775 - val_accuracy: 0.8500 - val_loss: 0.5187 - learning_rate: 1.0000e-05
# Epoch 181/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.9479 - loss: 0.1799 - val_accuracy: 0.8583 - val_loss: 0.5183 - learning_rate: 1.0000e-05
# Epoch 182/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9165 - loss: 0.2313
# Epoch 182: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_182_val_acc_0.8583.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.9333 - loss: 0.2122 - val_accuracy: 0.8583 - val_loss: 0.5166 - learning_rate: 1.0000e-05
# Epoch 183/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - accuracy: 0.9583 - loss: 0.1988 - val_accuracy: 0.8667 - val_loss: 0.5141 - learning_rate: 1.0000e-05
# Epoch 184/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9512 - loss: 0.1759
# Epoch 184: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_184_val_acc_0.8583.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 377ms/step - accuracy: 0.9500 - loss: 0.1772 - val_accuracy: 0.8583 - val_loss: 0.5136 - learning_rate: 1.0000e-05
# Epoch 185/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 236ms/step - accuracy: 0.9625 - loss: 0.1532 - val_accuracy: 0.8500 - val_loss: 0.5101 - learning_rate: 1.0000e-05
# Epoch 186/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9477 - loss: 0.1811
# Epoch 186: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_186_val_acc_0.8500.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.9500 - loss: 0.1780 - val_accuracy: 0.8500 - val_loss: 0.5071 - learning_rate: 1.0000e-05
# Epoch 187/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 0.9667 - loss: 0.1703 - val_accuracy: 0.8500 - val_loss: 0.5049 - learning_rate: 1.0000e-05
# Epoch 188/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9719 - loss: 0.1731
# Epoch 188: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_188_val_acc_0.8500.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 947ms/step - accuracy: 0.9771 - loss: 0.1681 - val_accuracy: 0.8500 - val_loss: 0.4991 - learning_rate: 1.0000e-05
# Epoch 189/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.9625 - loss: 0.1606 - val_accuracy: 0.8500 - val_loss: 0.4958 - learning_rate: 1.0000e-05
# Epoch 190/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9608 - loss: 0.1805
# Epoch 190: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_190_val_acc_0.8500.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 691ms/step - accuracy: 0.9500 - loss: 0.1987 - val_accuracy: 0.8500 - val_loss: 0.4948 - learning_rate: 1.0000e-05
# Epoch 191/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.9625 - loss: 0.1484 - val_accuracy: 0.8500 - val_loss: 0.4955 - learning_rate: 1.0000e-05
# Epoch 192/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9615 - loss: 0.1636
# Epoch 192: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_192_val_acc_0.8500.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 999ms/step - accuracy: 0.9625 - loss: 0.1616 - val_accuracy: 0.8500 - val_loss: 0.4960 - learning_rate: 1.0000e-05
# Epoch 193/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 251ms/step - accuracy: 0.9729 - loss: 0.1365 - val_accuracy: 0.8500 - val_loss: 0.4945 - learning_rate: 1.0000e-05
# Epoch 194/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9715 - loss: 0.1373
# Epoch 194: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_194_val_acc_0.8500.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.9708 - loss: 0.1465 - val_accuracy: 0.8500 - val_loss: 0.4915 - learning_rate: 1.0000e-05
# Epoch 195/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 247ms/step - accuracy: 0.9667 - loss: 0.1487 - val_accuracy: 0.8500 - val_loss: 0.4866 - learning_rate: 1.0000e-05
# Epoch 196/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9373 - loss: 0.1874
# Epoch 196: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_196_val_acc_0.8583.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 646ms/step - accuracy: 0.9583 - loss: 0.1522 - val_accuracy: 0.8583 - val_loss: 0.4848 - learning_rate: 1.0000e-05
# Epoch 197/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.9500 - loss: 0.1761 - val_accuracy: 0.8583 - val_loss: 0.4816 - learning_rate: 1.0000e-05
# Epoch 198/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9601 - loss: 0.1599
# Epoch 198: saving model to /content/drive/MyDrive/Colab Notebooks/Licenta/ResNet50_lfw50/Checkpoints/PersonCNN_ResNet50_lfw50_FT_epoch_198_val_acc_0.8583.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 743ms/step - accuracy: 0.9479 - loss: 0.1897 - val_accuracy: 0.8583 - val_loss: 0.4764 - learning_rate: 1.0000e-05
# Epoch 199/230
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s
keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.9750 - loss: 0.1191 - val_accuracy: 0.8750 - val_loss: 0.4478 - learning_rate: 2.5000e-06

# %%
import matplotlib.pyplot as plt

# Plot Training & Validation Accuracy and Loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import precision_score

# Note: Keras metrics in 'history' are tracked during training.
# If 'precision' was not in the compile metrics, we can calculate it from the validation predictions

# Assuming the user wants to see the trend of precision across the training history
# Since 'precision' wasn't explicitly in the .compile() metrics list,
# we'll display the macro-averaged precision from the classification results.

print(f"Overall Validation Macro Precision: {0.08:.2f}")

# Visualization of Precision per class based on the last evaluation
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average=None)

plt.figure(figsize=(12, 6))
plt.bar(class_names, precision, color='skyblue')
plt.title('Precision per Class (Validation Set)')
plt.xlabel('Individual')
plt.ylabel('Precision Score')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Overall Validation Macro Precision: 0.08

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Get predictions for the validation set
y_pred_probs = PersonCNN_ResNet50_lfw50.predict(val_ds)
y_pred = np.argmax(y_pred_probs, axis=1)

# Get true labels from the validation set
y_true = []
for images, labels in val_ds.unbatch():
    y_true.append(labels.numpy())
y_true = np.array(y_true)

# Generate Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.xticks(rotation=45)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 691ms/step

# %%
from sklearn.metrics import classification_report

# Generate and print the classification report
# Using the y_true and y_pred already calculated in the previous cell
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00         8
#      Colin_Powell       0.00      0.00      0.00        11
#   Donald_Rumsfeld       0.00      0.00      0.00        11
#     George_W_Bush       0.00      0.00      0.00         7
# Gerhard_Schroeder       0.14      0.17      0.15         6
#       Hugo_Chavez       0.22      0.20      0.21        10
#    Jacques_Chirac       0.20      0.20      0.20        15
#     Jean_Chretien       0.06      0.07      0.06        14
#     John_Ashcroft       0.00      0.00      0.00        11
# Junichiro_Koizumi       0.11      0.11      0.11         9
#   Serena_Williams       0.11      0.12      0.12         8
#        Tony_Blair       0.17      0.20      0.18        10
#
#          accuracy                           0.09       120
#         macro avg       0.08      0.09      0.09       120
#      weighted avg       0.09      0.09      0.09       120

# %%
from sklearn.metrics import classification_report

# Generate and print the classification report
# Using the y_true and y_pred already calculated in the previous cell
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00         8
#      Colin_Powell       0.00      0.00      0.00        11
#   Donald_Rumsfeld       0.00      0.00      0.00        11
#     George_W_Bush       0.00      0.00      0.00         7
# Gerhard_Schroeder       0.14      0.17      0.15         6
#       Hugo_Chavez       0.22      0.20      0.21        10
#    Jacques_Chirac       0.20      0.20      0.20        15
#     Jean_Chretien       0.06      0.07      0.06        14
#     John_Ashcroft       0.00      0.00      0.00        11
# Junichiro_Koizumi       0.11      0.11      0.11         9
#   Serena_Williams       0.11      0.12      0.12         8
#        Tony_Blair       0.17      0.20      0.18        10
#
#          accuracy                           0.09       120
#         macro avg       0.08      0.09      0.09       120
#      weighted avg       0.09      0.09      0.09       120
